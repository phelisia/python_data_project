# %%
from datasets import load_dataset
from matplotlib import pyplot as plt
import pandas as pd
dataset=load_dataset('lukebarousse/data_jobs')

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
df=dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df['job_posted_date']= pd.to_datetime(df.job_posted_date)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample()
# Out:
#        job_title_short                        job_title         job_location  \
# 484142  Data Scientist  Head of Data Science, Analytics  Türkenfeld, Germany
#
#                      job_via job_schedule_type  job_work_from_home  \
# 484142  via Jobs Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 484142         Germany 2023-06-14 14:20:04                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 484142                 False     Germany        None              NaN
#
#         salary_hour_avg                             company_name  \
# 484142              NaN  Fresenius Medical Care Deutschland GmbH
#
#                                              job_skills  \
# 484142  ['python', 'r', 'sql', 'tensorflow', 'pytorch']
#
#                                           job_type_skills
# 484142  {'libraries': ['tensorflow', 'pytorch'], 'prog...

# %%
df.sample(10)
# Out:
#              job_title_short  \
# 269315      Business Analyst
# 423280          Data Analyst
# 62689           Data Analyst
# 257267        Cloud Engineer
# 668607        Cloud Engineer
# 35101   Senior Data Engineer
# 139526         Data Engineer
# 514948   Senior Data Analyst
# 232372     Software Engineer
# 510908     Software Engineer
#
#                                                 job_title  \
# 269315               Business Application Analyst: 8098NB
# 423280                                   Data Analyst Jr.
# 62689                             Customer Analytics Lead
# 257267                         Service Management Analyst
# 668607  Vulnerability Management Analyst in IT Securit...
# 35101              Senior Data Engineer (Cloud Migration)
# 139526                        Data Engineer- Especialista
# 514948                                Senior Data Analyst
# 232372                                   Support Engineer
# 510908                                    Python Engineer
#
#                                            job_location  \
# 269315                       Western Cape, South Africa
# 423280                        Mexico City, CDMX, Mexico
# 62689                      Dubai - United Arab Emirates
# 257267                                        Australia
# 668607                                   Kraków, Poland
# 35101                                   Porto, Portugal
# 139526  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 514948                     Dubai - United Arab Emirates
# 232372                          Buenos Aires, Argentina
# 510908                       Johannesburg, South Africa
#
#                                               job_via job_schedule_type  \
# 269315                  via SimplyHired, South Africa         Full-time
# 423280                                via Ai-Jobs.net         Full-time
# 62689                                 via Trabajo.org         Full-time
# 257267                            via BeBee Australia         Full-time
# 668607                             via Theprotocol.it        Contractor
# 35101                                    via LinkedIn         Full-time
# 139526                       via Empregos Trabajo.org         Full-time
# 514948                                via Trabajo.org         Full-time
# 232372  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 510908                         via BeBee South Africa         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 269315               False          South Africa 2023-07-21 07:41:52
# 423280               False                Mexico 2023-04-12 16:33:58
# 62689                False  United Arab Emirates 2023-08-09 07:08:22
# 257267               False             Australia 2023-07-22 07:19:59
# 668607               False                Poland 2023-04-18 10:45:58
# 35101                False              Portugal 2023-09-09 13:13:56
# 139526               False                Brazil 2023-01-08 08:40:16
# 514948               False  United Arab Emirates 2023-08-03 11:27:30
# 232372               False             Argentina 2023-07-23 07:31:27
# 510908               False          South Africa 2023-02-09 11:39:09
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 269315                  False                 False          South Africa
# 423280                  False                 False                Mexico
# 62689                    True                 False  United Arab Emirates
# 257267                  False                 False             Australia
# 668607                   True                 False                Poland
# 35101                   False                 False              Portugal
# 139526                   True                 False                Brazil
# 514948                  False                 False  United Arab Emirates
# 232372                  False                 False             Argentina
# 510908                  False                 False          South Africa
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 269315        None              NaN              NaN
# 423280        year          53014.0              NaN
# 62689         None              NaN              NaN
# 257267        None              NaN              NaN
# 668607        None              NaN              NaN
# 35101         None              NaN              NaN
# 139526        None              NaN              NaN
# 514948        None              NaN              NaN
# 232372        None              NaN              NaN
# 510908        None              NaN              NaN
#
#                                    company_name  \
# 269315                                Exceed Hr
# 423280                              Media.Monks
# 62689                                Hello Chef
# 257267                                 Seqwater
# 668607  Sylvamo Global Business Services Center
# 35101                                   PrimeIT
# 139526                               TIM Brasil
# 514948                           Emirates Group
# 232372                                  Emprego
# 510908                         Progressive Edge
#
#                                                job_skills  \
# 269315                              ['azure', 'power bi']
# 423280           ['express', 'excel', 'looker', 'sheets']
# 62689                     ['mysql', 'postgresql', 'chef']
# 257267                                               None
# 668607                                               None
# 35101             ['python', 'sql', 'java', 'databricks']
# 139526  ['sql', 'r', 'scala', 'sas', 'sas', 'power bi'...
# 514948  ['sql', 'elasticsearch', 'snowflake', 'microst...
# 232372  ['java', 'visual basic', 'html', 'sql', 'micro...
# 510908  ['python', 'aws', 'kafka', 'angular', 'flask',...
#
#                                           job_type_skills
# 269315  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 423280  {'analyst_tools': ['excel', 'looker', 'sheets'...
# 62689   {'databases': ['mysql', 'postgresql'], 'other'...
# 257267                                               None
# 668607                                               None
# 35101   {'cloud': ['databricks'], 'programming': ['pyt...
# 139526  {'analyst_tools': ['sas', 'power bi', 'tableau...
# 514948  {'analyst_tools': ['microstrategy', 'power bi'...
# 232372  {'analyst_tools': ['microstrategy'], 'programm...
# 510908  {'cloud': ['aws'], 'libraries': ['kafka'], 'ot...

# %%
df.sample(10,random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
dataset=load_dataset('lukebarousse/data_jobs') 
df_original=dataset['train'].to_pandas()
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\pheli\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Fri Jun 21 13:28:37 2024).

# %%
df_altered=df_original.copy()

# %%
df_original.loc[:5,'salary_hour_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_hour_avg, dtype: float64

# %%
median_hourly=df_altered['salary_hour_avg'].median()

# %%
df_altered['salary_hour_avg']=df_altered['salary_hour_avg'].fillna(median_hourly)

# %%
df_altered.loc[:10,'salary_hour_avg']
# Out:
# 0     45.98
# 1     45.98
# 2     45.98
# 3     45.98
# 4     45.98
# 5     45.98
# 6     45.98
# 7     45.98
# 8     45.98
# 9     45.98
# 10    45.98
# Name: salary_hour_avg, dtype: float64
