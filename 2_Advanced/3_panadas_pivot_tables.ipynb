# %%
from datasets import load_dataset
from matplotlib import pyplot as plt
import pandas as pd
dataset=load_dataset('lukebarousse/data_jobs')

# %%
df=dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740     Software Engineer  ...              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df['job_posted_date']=pd.to_datetime(df.job_posted_date)

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740     Software Engineer  ...              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %% [markdown]
# Count of Job Titles

# %%
df.pivot_table(index='job_title_short',aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(index='job_title_short',aggfunc='count')
# Out:
#                            company_name  ...  search_location
# job_title_short                          ...
# Business Analyst                  49063  ...            49063
# Cloud Engineer                    12331  ...            12331
# Data Analyst                     196070  ...           196075
# Data Engineer                    186236  ...           186241
# Data Scientist                   172281  ...           172286
# Machine Learning Engineer         14080  ...            14080
# Senior Data Analyst               29216  ...            29216
# Senior Data Engineer              44563  ...            44563
# Senior Data Scientist             36957  ...            36957
# Software Engineer                 44926  ...            44929
#
# [10 rows x 16 columns]

# %%
df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')
# Out:
# job_title_short  Business Analyst  ...  Software Engineer
# job_country                        ...
# Albania                       NaN  ...                NaN
# Algeria                       NaN  ...                NaN
# Argentina                 71100.0  ...           174500.0
# Armenia                       NaN  ...                NaN
# Australia                 70000.0  ...           118350.0
# ...                           ...  ...                ...
# Uruguay                       NaN  ...                NaN
# Uzbekistan                    NaN  ...                NaN
# Vietnam                   79200.0  ...            53600.0
# Zambia                        NaN  ...                NaN
# Zimbabwe                      NaN  ...                NaN
#
# [108 rows x 10 columns]

# %%
top_countries=df['job_country'].value_counts().head(6).index

# %%
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
df_job_country_salary=df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='median'
)

# %%
df_job_country_salary=df_job_country_salary.loc[top_countries]

# %%
df_job_country_salary
# Out:
# job_title_short  Business Analyst  ...  Software Engineer
# job_country                        ...
# United States             90000.0  ...           130000.0
# India                     64800.0  ...            79200.0
# United Kingdom            56700.0  ...            89100.0
# France                    89100.0  ...           142500.0
# Germany                   89100.0  ...            84975.0
# Spain                     86400.0  ...            77050.0
#
# [6 rows x 10 columns]

# %%
job_titles=['Data Analyst','Data Scientist','Data Engineer']

# %%
job_titles
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_job_country_salary = df_job_country_salary[job_titles]

# %%
df_job_country_salary
# Out:
# job_title_short  Data Analyst  Data Scientist  Data Engineer
# job_country
# United States         90000.0        130000.0       125000.0
# India                100500.0        114008.0       147500.0
# United Kingdom        87750.0        105300.0       110000.0
# France                69175.0         88128.0        98301.5
# Germany              103750.0        131560.0       147500.0
# Spain                 91977.0         88128.0       133000.0

# %%
df_job_country_salary.plot(kind='bar')
plt.title('Median Salary by Job Title and Job Country')
plt.ylabel('Median Salary in USD')
plt.xlabel('')
plt.xticks(rotation=45 ,ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'United States'),
#   Text(1, 0, 'India'),
#   Text(2, 0, 'United Kingdom'),
#   Text(3, 0, 'France'),
#   Text(4, 0, 'Germany'),
#   Text(5, 0, 'Spain')])
